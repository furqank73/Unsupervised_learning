# %% [markdown]
# <style>
# .isolation-title {
#     color: #2b7a78;
#     font-size: 2em;
#     font-weight: bold;
#     margin-bottom: 0.5em;
# }
# .isolation-desc {
#     color: #17252a;
#     background: #def2f1;
#     border-left: 6px solid #3aafa9;
#     padding: 1em;
#     border-radius: 8px;
#     font-size: 1.1em;
#     line-height: 1.6;
# }
# </style>
#
# <div class="isolation-title">What is Isolation Forest?</div>
# <div class="isolation-desc">
# Isolation Forest is a state-of-the-art anomaly detection algorithm which is very famous for its efficiency and simplicity. By removing anomalies from a dataset using binary partitioning, it quickly identifies outliers with minimal computational overhead, making it the way to go for anomalies in areas ranging from cybersecurity to finance. In this article, we are going to explore the fundamentals of the Isolation Forest algorithm.
# </div>

# %%
import matplotlib.pyplot as plt

# Before anomaly detection
plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c='gray', label='All Data')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Before Isolation Forest')
plt.legend()
plt.grid(True)

# After anomaly detection
plt.subplot(1, 2, 2)
plt.scatter(X[y_pred == 1][:, 0], X[y_pred == 1][:, 1], c='blue', label='Normal')
plt.scatter(X[y_pred == -1][:, 0], X[y_pred == -1][:, 1], c='red', label='Anomaly', marker='x', s=100)
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('After Isolation Forest')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
